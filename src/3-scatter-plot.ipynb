# %% [markdown]
# ### Exercise 3: Scatter Plot with Annotations

# %%
# TASK: Create a scatter plot with x = [1, 2, 3, 4, 5] and y = [2, 4, 6, 8, 10].
# Annotate each point with its (x, y) value, and set the title as 'Scatter Plot with Annotations'.

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create scatter plot
plt.scatter(x, y, color='blue', marker='o', label='Data Points')

# Annotate each point with its (x, y) value
for i in range(len(x)):
    plt.text(x[i], y[i], f'({x[i]},{y[i]})', fontsize=12, ha='right', va='bottom')

    # Labels and title
    plt.xlabel('X values')
    plt.ylabel('Y values')
    plt.title('Scatter Plot with Annotations')
    plt.legend()
    plt.grid(True)

    # Show the plot
    plt.show()
# Out:
# /tmp/ipykernel_10642/10516015.py:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
